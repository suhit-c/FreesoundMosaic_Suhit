# %% [markdown]
# # 1) Create source sound collection
#
# This notebook includes the code to create the collection of sounds that will later be used as source material for our audio mosaicing application. The collection of sounds is created by defining a number of queries to be performed using the Freesound API and concatenanting the results of each query. A number of metadata fields are stored for each sound in the collection and saved into a Pandas DataFrame object and CSV file in disk. For each sound in the collection, we also download an OGG preview and store it in disk.
#
# This notebook uses the `freesound` Python package for interacting with the Freesound API. The source code for this package can be found here: https://github.com/mtg/freesound-python. In this repository you'll find a Python script with [examples](https://github.com/MTG/freesound-python/blob/master/examples.py) to learn how to interact with the API. Nevertheless, if you are further interested in the Freesound API, check the [API documentation](http://freesound.org/docs/api/) which provides more information.
#
# **NOTE**: A Freesound API key is provided in this notebook, but you should make a Freesound account and get your own key. You can get a key here: https://freesound.org/apiv2/apply/

# %%
# Essentia
# !pip install essentia
# Freesound-python
# !pip install git+https://github.com/mtg/freesound-python.git
# Mount drive and cd to notebook folder
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Collecting essentia
#   Downloading essentia-2.1b6.dev1110-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.10/dist-packages (from essentia) (1.25.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from essentia) (1.16.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from essentia) (6.0.1)
# Installing collected packages: essentia
# Successfully installed essentia-2.1b6.dev1110
# Collecting git+https://github.com/mtg/freesound-python.git
#   Cloning https://github.com/mtg/freesound-python.git to /tmp/pip-req-build-mtsluyzr
#   Running command git clone --filter=blob:none --quiet https://github.com/mtg/freesound-python.git /tmp/pip-req-build-mtsluyzr
#   Resolved https://github.com/mtg/freesound-python.git to commit 5be99a3689d17303c01cb122bbb0d5a96eba04f6
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests<3.0,>2.27 in /usr/local/lib/python3.10/dist-packages (from freesound-python==1.1) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>2.27->freesound-python==1.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>2.27->freesound-python==1.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>2.27->freesound-python==1.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>2.27->freesound-python==1.1) (2024.2.2)
# Building wheels for collected packages: freesound-python
#   Building wheel for freesound-python (pyproject.toml) ... done
#   Created wheel for freesound-python: filename=freesound_python-1.1-py3-none-any.whl size=6714 sha256=73d98a461206e96a43adf935667a7c66d70695b1419e8d84b8459876c683ff4b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_9uczfz0/wheels/2d/14/a0/4f60908e5b801658e71ba0d38958c2e2baef3573ef368db670
# Successfully built freesound-python
# Installing collected packages: freesound-python
# Successfully installed freesound-python-1.1
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/SMC/AMPLab2324/AMPLAB 2024 Freesound session'
# Out:
# /content/drive/MyDrive/SMC/AMPLab2324/AMPLAB 2024 Freesound session

# %%
import os
import pandas as pd
import numpy as np
import freesound
from IPython.display import display

FREESOUND_API_KEY = '36e286ba563287f86eed608c13cacd520ced010e'  # Please replace by your own Freesound API key
FILES_DIR = 'files'  # Place where to store the downloaded diles. Will be relative to the current folder.
DATAFRAME_FILENAME = 'dataframe.csv'  # File where we'll store the metadata of our sounds collection
FREESOUND_STORE_METADATA_FIELDS = ['id', 'name', 'username', 'previews', 'license', 'tags']  # Freesound metadata properties to store

freesound_client = freesound.FreesoundClient()
freesound_client.set_token(FREESOUND_API_KEY)
if not os.path.exists(FILES_DIR): os.mkdir(FILES_DIR)

# %%
# Define some util functions

def query_freesound(query, filter, num_results=10):
    """Queries freesound with the given query and filter values.
    If no filter is given, a default filter is added to only get sounds shorter than 30 seconds.
    """
    if filter is None:
        filter = 'duration:[0 TO 30]'  # Set default filter
    pager = freesound_client.text_search(
        query = query,
        filter = filter,
        fields = ','.join(FREESOUND_STORE_METADATA_FIELDS),
        group_by_pack = 1,
        page_size = num_results
    )
    return [sound for sound in pager]

def retrieve_sound_preview(sound, directory):
    """Download the high-quality OGG sound preview of a given Freesound sound object to the given directory.
    """
    return freesound.FSRequest.retrieve(
        sound.previews.preview_hq_ogg,
        freesound_client,
        os.path.join(directory, sound.previews.preview_hq_ogg.split('/')[-1])
    )

def make_pandas_record(sound):
    """Create a dictionary with the metadata that we want to store for each sound.
    """
    record = {key: sound.as_dict()[key] for key in FREESOUND_STORE_METADATA_FIELDS}
    del record['previews']  # Don't store previews dict in record
    record['freesound_id'] = record['id']  # Rename 'id' to 'freesound_id'
    del record['id']
    record['path'] = "files/" + sound.previews.preview_hq_ogg.split("/")[-1]  # Store path of downloaded file
    return record

# %%
# Build our collection of sounds

# Our collection of sounds is made by appending the results of a number of different queries to freesound
# The query terms, query filters and the number of results per query are all defined here.
# Information about how to define filters can be found in the Freesound API documentation: https://freesound.org/docs/api/resources_apiv2.html#request-parameters-text-search-parameters
freesound_queries = [
    {
        'query': 'dog bark',
        'filter': None,
        'num_results': 20,
    },
    {
        'query': 'percussion sounds',
        'filter': 'duration:[0 TO 1]',
        'num_results': 20,
    },
    {
        'query': 'vocals',
        'filter': 'duration:[1 TO 2]',
        'num_results': 20,
    },
]

# Do all queries and concatenate the results in a single list of sounds
sounds = sum([query_freesound(query['query'], query['filter'], query['num_results']) for query in freesound_queries],[])

# Download the sounds and save them to FILES_DIR folder
for count, sound in enumerate(sounds):
    print('Downloading sound with id {0} [{1}/{2}]'.format(sound.id, count + 1, len(sounds)))
    retrieve_sound_preview(sound, 'files/')

# Make a Pandas DataFrame with the metadata of our sound collection and save it
df =  pd.DataFrame([make_pandas_record(s) for s in sounds])
df.to_csv(DATAFRAME_FILENAME)
print('Saved DataFrame with {0} entries! {1}'.format(len(df), DATAFRAME_FILENAME))

# Show the contents of our DataFrame (the metadata of our source collection)
display(df)
# Out:
# Downloading sound with id 236280 [1/60]
# Downloading sound with id 612856 [2/60]
# Downloading sound with id 625498 [3/60]
# Downloading sound with id 418108 [4/60]
# Downloading sound with id 649020 [5/60]
# Downloading sound with id 485962 [6/60]
# Downloading sound with id 440865 [7/60]
# Downloading sound with id 580213 [8/60]
# Downloading sound with id 495658 [9/60]
# Downloading sound with id 400916 [10/60]
# Downloading sound with id 277058 [11/60]
# Downloading sound with id 242403 [12/60]
# Downloading sound with id 160092 [13/60]
# Downloading sound with id 157322 [14/60]
# Downloading sound with id 199261 [15/60]
# Downloading sound with id 609488 [16/60]
# Downloading sound with id 640726 [17/60]
# Downloading sound with id 180977 [18/60]
# Downloading sound with id 608732 [19/60]
# Downloading sound with id 372571 [20/60]
# Downloading sound with id 124111 [21/60]
# Downloading sound with id 260515 [22/60]
# Downloading sound with id 183115 [23/60]
# Downloading sound with id 57041 [24/60]
# Downloading sound with id 463937 [25/60]
# Downloading sound with id 463936 [26/60]
# Downloading sound with id 338748 [27/60]
# Downloading sound with id 463938 [28/60]
# Downloading sound with id 424373 [29/60]
# Downloading sound with id 522980 [30/60]
# Downloading sound with id 184087 [31/60]
# Downloading sound with id 621514 [32/60]
# Downloading sound with id 621574 [33/60]
# Downloading sound with id 621834 [34/60]
# Downloading sound with id 622172 [35/60]
# Downloading sound with id 622651 [36/60]
# Downloading sound with id 622779 [37/60]
# Downloading sound with id 612584 [38/60]
# Downloading sound with id 347128 [39/60]
# Downloading sound with id 347127 [40/60]
# Downloading sound with id 86214 [41/60]
# Downloading sound with id 554949 [42/60]
# Downloading sound with id 703654 [43/60]
# Downloading sound with id 42213 [44/60]
# Downloading sound with id 61138 [45/60]
# Downloading sound with id 641554 [46/60]
# Downloading sound with id 23877 [47/60]
# Downloading sound with id 644760 [48/60]
# Downloading sound with id 642943 [49/60]
# Downloading sound with id 52694 [50/60]
# Downloading sound with id 87675 [51/60]
# Downloading sound with id 14840 [52/60]
# Downloading sound with id 662611 [53/60]
# Downloading sound with id 653024 [54/60]
# Downloading sound with id 653229 [55/60]
# Downloading sound with id 31434 [56/60]
# Downloading sound with id 246218 [57/60]
# Downloading sound with id 643376 [58/60]
# Downloading sound with id 205827 [59/60]
# Downloading sound with id 642917 [60/60]
# Saved DataFrame with 60 entries! dataframe.csv
#                                                  name             username  \
# 0                  Jazz the Dog Howl & Bark (053).wav        delphidebrain
# 1                                  Dogs bark and howl             WeakWero
# 2                              Animal Dog Bark 01.wav         abhisheky948
# 3                                    dog tripple bark          crazymonke9
# 4                           Dog barking, 15m distance       AtoMediaDesign
# 5                        Dog Barking Distance - 1.wav             SpaceJoe
# 6               Angry big dog barking - Far [d15].wav                  v23
# 7                       004 - Dog Barking at Door.wav      TrashCanStudios
# 8                                            Dog Bark               aunrea
# 9                          dogs_barking_mono_4824.wav            Mystikuum
# 10                                    Single Dog Bark           kwahmah_02
# 11                               Midsized Dog Bark 02              noctaro
# 12                                         Dog bark 1          jorickhoofd
# 13                 Dog Bark Staffordshire Bullterrier                Anton
# 14                    A dog barking (close recording)          felix.blume
# 15                         10413 killer dog barks.wav          Robinhood76
# 16                                        Dog Barking          iainmccurdy
# 17                                        Barking Dog        SuperStudioBR
# 18                   Pomeranian Small Dog Barking.mp3              yunjish
# 19                    Dog Shih Tzu Bark Series 01.wav        Glitchedtones
# 20                                        T Sound.wav           connersaw8
# 21                 electribe-kicks slice 21 [A-6].wav          soneproject
# 22                                   prc_appet909.wav                 DWSD
# 23                                 suctionkickpot.wav       NoiseCollector
# 24                                       Lighter Fire            RicardoRG
# 25                                  Small Case Closed            RicardoRG
# 26           Perc. coffee tin 03 muted March 2016.wav          cabled_mess
# 27                                         Velcro Rip            RicardoRG
# 28                             percussion sound 1.wav              Elnosos
# 29                                         Kick 2.wav     radiohummingbird
# 30                             canpop13percussion.wav       NoiseCollector
# 31                          YP Plague Percussion A-14                 nlux
# 32                          YP Plague Percussion B-08                 nlux
# 33                          YP Plague Percussion C-06                 nlux
# 34                          YP Plague Percussion D-03                 nlux
# 35                          YP Plague Percussion E-08                 nlux
# 36                          YP Plague Percussion F-03                 nlux
# 37  Sofa hand percussion (kick sound)  48000 Hz 24...           diogorusso
# 38  Nova Analog Castanets Click Clack Percussion -...  NovaSoundTechnology
# 39  Peaceful Flare Stick Snap Snare Drum Percussio...  NovaSoundTechnology
# 40                      FEMALE VOCAL CRESCENDO 01.wav              sandyrb
# 41           [Vocal] distorted lollievox vocal sample          waveplaySFX
# 42                     Electric Piano with Vocals Gm7           1ClickInfo
# 43      Dj - www.hardsamples.com - by shock force.wav           shockforce
# 44                                     I Like 002.aif        humphreyswill
# 45                 Yes yall with Deep Low Voice Vocal           Duisterwho
# 46                   vocal_range_altogether_22mix.mp3               dwsolo
# 47             Vocal - hello laugh - chuckle greeting           Duisterwho
# 48                              I am a cowboy - vocal           Duisterwho
# 49                                     Vocal Roll.wav            KatHakaku
# 50                                              e.wav                kospy
# 51                                   noizesinging.wav        RandomInsults
# 52                                   147_IDK b1tchvox           gunnbladez
# 53                                       woahohoh.wav             nharasha
# 54                                         woahoh.wav             nharasha
# 55                                         goitu2.wav         Rhedcerulean
# 56                   atmospheric vocals short Aiy.wav          AndreAngelo
# 57                     Thats not funny Bitch - vocals           Duisterwho
# 58                                 REFLEXVOCALS03.wav              mushino
# 59  Dirty motherfucker - vocal one shot low deep v...           Duisterwho
#
#                                               license  \
# 0     https://creativecommons.org/licenses/by-nc/4.0/
# 1   http://creativecommons.org/publicdomain/zero/1.0/
# 2   http://creativecommons.org/publicdomain/zero/1.0/
# 3        https://creativecommons.org/licenses/by/4.0/
# 4        https://creativecommons.org/licenses/by/4.0/
# 5   http://creativecommons.org/publicdomain/zero/1.0/
# 6   http://creativecommons.org/publicdomain/zero/1.0/
# 7        https://creativecommons.org/licenses/by/4.0/
# 8   http://creativecommons.org/publicdomain/zero/1.0/
# 9   http://creativecommons.org/publicdomain/zero/1.0/
# 10  http://creativecommons.org/publicdomain/zero/1.0/
# 11       https://creativecommons.org/licenses/by/4.0/
# 12       https://creativecommons.org/licenses/by/4.0/
# 13       https://creativecommons.org/licenses/by/4.0/
# 14  http://creativecommons.org/publicdomain/zero/1.0/
# 15    https://creativecommons.org/licenses/by-nc/4.0/
# 16       https://creativecommons.org/licenses/by/4.0/
# 17  http://creativecommons.org/publicdomain/zero/1.0/
# 18  http://creativecommons.org/publicdomain/zero/1.0/
# 19  http://creativecommons.org/publicdomain/zero/1.0/
# 20  http://creativecommons.org/publicdomain/zero/1.0/
# 21  http://creativecommons.org/publicdomain/zero/1.0/
# 22        http://creativecommons.org/licenses/by/3.0/
# 23        http://creativecommons.org/licenses/by/3.0/
# 24  http://creativecommons.org/publicdomain/zero/1.0/
# 25  http://creativecommons.org/publicdomain/zero/1.0/
# 26  http://creativecommons.org/publicdomain/zero/1.0/
# 27        http://creativecommons.org/licenses/by/3.0/
# 28  http://creativecommons.org/publicdomain/zero/1.0/
# 29       https://creativecommons.org/licenses/by/4.0/
# 30        http://creativecommons.org/licenses/by/3.0/
# 31       https://creativecommons.org/licenses/by/4.0/
# 32       https://creativecommons.org/licenses/by/4.0/
# 33       https://creativecommons.org/licenses/by/4.0/
# 34       https://creativecommons.org/licenses/by/4.0/
# 35       https://creativecommons.org/licenses/by/4.0/
# 36       https://creativecommons.org/licenses/by/4.0/
# 37  http://creativecommons.org/publicdomain/zero/1.0/
# 38  http://creativecommons.org/publicdomain/zero/1.0/
# 39  http://creativecommons.org/publicdomain/zero/1.0/
# 40       https://creativecommons.org/licenses/by/4.0/
# 41  http://creativecommons.org/publicdomain/zero/1.0/
# 42    https://creativecommons.org/licenses/by-nc/4.0/
# 43        http://creativecommons.org/licenses/by/3.0/
# 44       https://creativecommons.org/licenses/by/4.0/
# 45  http://creativecommons.org/publicdomain/zero/1.0/
# 46  http://creativecommons.org/licenses/sampling+/...
# 47  http://creativecommons.org/publicdomain/zero/1.0/
# 48  http://creativecommons.org/publicdomain/zero/1.0/
# 49  http://creativecommons.org/publicdomain/zero/1.0/
# 50  http://creativecommons.org/licenses/sampling+/...
# 51  http://creativecommons.org/licenses/sampling+/...
# 52       https://creativecommons.org/licenses/by/4.0/
# 53  http://creativecommons.org/publicdomain/zero/1.0/
# 54  http://creativecommons.org/publicdomain/zero/1.0/
# 55  http://creativecommons.org/licenses/sampling+/...
# 56        http://creativecommons.org/licenses/by/3.0/
# 57  http://creativecommons.org/publicdomain/zero/1.0/
# 58       https://creativecommons.org/licenses/by/4.0/
# 59  http://creativecommons.org/publicdomain/zero/1.0/
#
#                                                  tags  freesound_id  \
# 0   [Barking, Jazz, Barks, Dog, Howling, Wolf, Ani...        236280
# 1      [barking, whine, dog, bark, puppy, dogs, howl]        612856
# 2                                 [Bark, Dog, Animal]        625498
# 3   [growling, growl, animals, barking, pet, angry...        418108
# 4                    [woof, bark, dogs, dog, barking]        649020
# 5   [distance, barking, dog, woof, attack, backgro...        485962
# 6               [barking, far, big, angry, dog, bark]        440865
# 7   [Foley, Barking, Dog, Canine, Ruff, Woof, Bark...        580213
# 8                                    [pet, bark, dog]        495658
# 9    [barking, dog, canine, woof, animal, bark, dogs]        400916
# 10  [animal, pet, dog, public-domain, woof, single...        277058
# 11  [barking, pet, bellen, dog, woof, animal, bark...        242403
# 12                          [average-size, bark, Dog]        160092
# 13  [sennheiser, sound-devices, dog, m-s, stafford...        157322
# 14  [moan, blume, barking, usa, grunting, felix, d...        199261
# 15  [barking, watching, household, killer, dog, wo...        609488
# 16  [barking, woof, barks, dog-barking, dog, bow-w...        640726
# 17                  [bark, happy, loud, dog, barking]        180977
# 18  [barking, Pomeranian, dog, yappy, yip, bark, p...        608732
# 19             [Bark, Shih-Tzu, Dog, Animal, Barking]        372571
# 20  [beatboxing, connersaw8, mouth, percussion, so...        124111
# 21  [bassdrum, electribe, sample, sounds, sub, fac...        260515
# 22  [perc, hits, drums, house, Percussion, music, ...        183115
# 23    [dangerous, foley, kitchen, percussion, sounds]         57041
# 24  [152, random, Percussion, Flint, Lighter, Stri...        463937
# 25  [Sound, Music152, Drum, Garcia, Percussion, 15...        463936
# 26  [sample-pack, sampling, sample, raw, Sampler, ...        338748
# 27  [sound, 152, Drum, Garcia, Random, Percussion,...        463938
# 28              [perc, percussion, percs, percussive]        424373
# 29  [one-shot, sample-pack, drum, rhythm, percussi...        522980
# 30                         [Pringle, percussion, can]        184087
# 31  [black-death, illbient, lo-fi, glitch, beats, ...        621514
# 32  [black-death, illbient, lo-fi, glitch, beats, ...        621574
# 33  [black-death, illbient, lo-fi, glitch, beats, ...        621834
# 34  [black-death, illbient, lo-fi, glitch, beats, ...        622172
# 35  [black-death, illbient, lo-fi, glitch, beats, ...        622651
# 36  [percs, electronic, pestis, drumbeat, machine,...        622779
# 37                          [percussion, punch, sofa]        612584
# 38  [Hip, Sound, Erace, Drum, Drums, Nova, Percuss...        347128
# 39  [Hip, Sound, Erace, Drum, Drums, Nova, Percuss...        347127
# 40  [129bpm, female, male, party, shot, shots, sta...         86214
# 41  [webb, driven, vocal, indie, overdriven, aesth...        554949
# 42            [gm7, keyboard, electric-piano, vocals]        703654
# 43  [acapella, acepellas, dj, gabber, hardcore, ha...         42213
# 44                          [male, processed, vocals]         61138
# 45  [scary, male, Monster, spoken, text, creature,...        641554
# 46       [alto, bass, notes, tenor, together, vocals]         23877
# 47  [mp3, laugh, chuckle, one-shot, acapella, male...        644760
# 48  [funny, male, witch, spoken, over, vocal, fant...        642943
# 49    [kaoss, musik, noisy, processed, vocals, weird]         52694
# 50                  [catalan, e, male, vocals, voice]         87675
# 51         [field-recordings, noise, singing, vocals]         14840
# 52                            [vocals, IDK, b1tchvox]        662611
# 53       [acapella, vocals, highpitched, vox, scream]        653024
# 54                 [screaming, vocals, vox, abrasive]        653229
# 55                                       [fx, vocals]         31434
# 56         [short, aiy, horror, vocal, vocals, voice]        246218
# 57  [happening, floor, spoken, speech, english, Un...        643376
# 58                            [raga, vocals, mushino]        205827
# 59  [naughty, shot, adults, spoken, text, deep, on...        642917
#
#                             path
# 0     files/236280_180659-hq.ogg
# 1   files/612856_13194336-hq.ogg
# 2   files/625498_13366994-hq.ogg
# 3    files/418108_6078577-hq.ogg
# 4    files/649020_3571340-hq.ogg
# 5    files/485962_6150892-hq.ogg
# 6    files/440865_1751509-hq.ogg
# 7   files/580213_12973965-hq.ogg
# 8    files/495658_7932944-hq.ogg
# 9    files/400916_1643758-hq.ogg
# 10   files/277058_4486188-hq.ogg
# 11   files/242403_4165591-hq.ogg
# 12   files/160092_2888453-hq.ogg
# 13        files/157322_58-hq.ogg
# 14   files/199261_1661766-hq.ogg
# 15    files/609488_321967-hq.ogg
# 16   files/640726_3655844-hq.ogg
# 17   files/180977_3370987-hq.ogg
# 18   files/608732_8729843-hq.ogg
# 19   files/372571_3294528-hq.ogg
# 20   files/124111_2219481-hq.ogg
# 21   files/260515_2127539-hq.ogg
# 22   files/183115_2394245-hq.ogg
# 23       files/57041_4948-hq.ogg
# 24   files/463937_9754348-hq.ogg
# 25   files/463936_9754348-hq.ogg
# 26   files/338748_5450487-hq.ogg
# 27   files/463938_9754348-hq.ogg
# 28   files/424373_7099958-hq.ogg
# 29  files/522980_11586518-hq.ogg
# 30      files/184087_4948-hq.ogg
# 31   files/621514_9047165-hq.ogg
# 32   files/621574_9047165-hq.ogg
# 33   files/621834_9047165-hq.ogg
# 34   files/622172_9047165-hq.ogg
# 35   files/622651_9047165-hq.ogg
# 36   files/622779_9047165-hq.ogg
# 37  files/612584_11206457-hq.ogg
# 38    files/347128_369949-hq.ogg
# 39    files/347127_369949-hq.ogg
# 40      files/86214_14771-hq.ogg
# 41   files/554949_1676145-hq.ogg
# 42  files/703654_15259013-hq.ogg
# 43     files/42213_429662-hq.ogg
# 44     files/61138_751763-hq.ogg
# 45  files/641554_13590673-hq.ogg
# 46     files/23877_156279-hq.ogg
# 47  files/644760_13590673-hq.ogg
# 48  files/642943_13590673-hq.ogg
# 49     files/52694_164285-hq.ogg
# 50    files/87675_1132904-hq.ogg
# 51      files/14840_43870-hq.ogg
# 52   files/662611_1603602-hq.ogg
# 53   files/653024_5657141-hq.ogg
# 54   files/653229_5657141-hq.ogg
# 55     files/31434_259814-hq.ogg
# 56   files/246218_4523435-hq.ogg
# 57  files/643376_13590673-hq.ogg
# 58   files/205827_3848324-hq.ogg
# 59  files/642917_13590673-hq.ogg
